# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator
import napari
from skimage.transform import radon, resize
from skimage.transform import iradon, iradon_sart
from skimage.metrics import structural_similarity as ssim
from scipy.optimize import curve_fit
from src.functions import (  # self defined (somewhat)
    generate_num_projections,
    generate_sparse_sinogram,
    order_angles_golden_ratio,
    modified_sart_plus_tv,
    add_salt_pepper,
    add_gaussian_noise,
    calculate_ssim,
    calculate_mse,
    iterative_sart,
)
from skimage.data import shepp_logan_phantom
from skimage import io
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 10
#       6 from skimage.transform import radon, resize
#       7 from skimage.transform import iradon, iradon_sart
#       8 from skimage.metrics import structural_similarity as ssim
#       9 from scipy.optimize import curve_fit
# ---> 10 from src.functions import (  # self defined (somewhat)
#      11     generate_num_projections,
#      12     generate_sparse_sinogram,
#      13     order_angles_golden_ratio,
#
# ModuleNotFoundError: No module named 'src'

# %%
# torus image code, used in lots of cells

# R value is radius of larger circle
big_r = 4

# r value is radius of smaller circle
r = 2

x_vals = np.linspace(-7, 7, 200)
y_vals = np.linspace(-7, 7, 200)
z_vals = np.linspace(
    -7, 7, 200
)  # can change number of 'layers' of 2D images to simuate number of slices taken
i, j, k = np.meshgrid(x_vals, y_vals, z_vals)

# create 3d intensity array
torus_image = (np.sqrt((np.sqrt(i**2 + j**2) - big_r) ** 2 + k**2) < r).astype(
    float
)  # astype(float) evaluates boolean expresion with 1 or 0

# %% [markdown]
# # Torus generation

# %%
# R value is radius of larger circle
large_r = 5

# r value is radius of smaller circle
r = 2

x_vals = np.linspace(-5, 5, 100)
y_vals = np.linspace(-5, 5, 100)
i, j = np.meshgrid(x_vals, y_vals)

phi = np.linspace(0, 2 * np.pi, 100)
theta = np.linspace(0, np.pi, 100)
PHI, THETA = np.meshgrid(phi, theta)
X = r * np.sin(THETA) * np.cos(PHI)
Y = r * np.sin(THETA) * np.sin(PHI)
Z = r * np.cos(THETA)

# Generate graph
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
# Plot the surface.
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm, linewidth=0, antialiased=False)

# Customize the z axis.
ax.zaxis.set_major_locator(LinearLocator(10))
# A StrMethodFormatter is used automatically
ax.zaxis.set_major_formatter("{x:.02f}")

# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=1)

plt.show()

# %%
x_vals = np.linspace(-5, 5, 1000)
y_vals = np.linspace(-5, 5, 1000)
z_vals = np.linspace(-5, 5, 1000)
i, j, k = np.meshgrid(x_vals, y_vals, z_vals)
sphere_image = (np.sqrt(i**2 + j**2 + k**2) < r).astype(
    float
)  # astype(float) evaluates boolean expresion with 1 or 0

viewer = napari.Viewer()
viewer.add_image(sphere_image, name="sphere_image")
napari.run()

# %%
# R value is radius of larger circle
big_r = 4

# r value is radius of smaller circle
r = 2

x_vals = np.linspace(-5, 5, 100)
y_vals = np.linspace(-5, 5, 100)
i, j = np.meshgrid(x_vals, y_vals)

phi = np.linspace(0, 2 * np.pi, 100)
theta = np.linspace(0, 2 * np.pi, 100)
PHI, THETA = np.meshgrid(phi, theta)
X = (big_r + r * np.sin(THETA)) * np.cos(PHI)
Y = (big_r + r * np.sin(THETA)) * np.sin(PHI)
Z = r * np.cos(THETA)

# Generate graph
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
# Plot the surface.
# This is usfeful for visualisation, but really we have just supplied the points along the surface of the torus.
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm, linewidth=0, antialiased=False)

# Customize the z axis.
ax.zaxis.set_major_locator(LinearLocator(10))
# A StrMethodFormatter is used automatically
ax.zaxis.set_major_formatter("{x:.02f}")

# set equal aspect ratio
ax.set_aspect("equal")

# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=1)

plt.show()

# %%
x_vals = np.linspace(-7, 7, 200)
y_vals = np.linspace(-7, 7, 200)
z_vals = np.linspace(
    -7, 7, 200
)  # can change number of 'layers' of 2D images to simuate number of slices taken
i, j, k = np.meshgrid(x_vals, y_vals, z_vals)

# create 3d intensity array
torus_image = (np.sqrt((np.sqrt(i**2 + j**2) - big_r) ** 2 + k**2) < r).astype(
    float
)  # astype(float) evaluates boolean expresion with 1 or 0

viewer = napari.Viewer()
viewer.add_image(torus_image, name="torus_image")
napari.run()
# Out:
# libEGL warning: failed to get driver name for fd -1
#
# libEGL warning: MESA-LOADER: failed to retrieve device information
#
# libEGL warning: failed to get driver name for fd -1
#
# MESA: error: ZINK: failed to choose pdev
# libEGL warning: egl: failed to create dri2 screen
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 13
#       9 torus_image = (np.sqrt((np.sqrt(i**2 + j**2) - big_r) ** 2 + k**2) < r).astype(
#      10     float
#      11 )  # astype(float) evaluates boolean expresion with 1 or 0
#      12
# ---> 13 viewer = napari.Viewer()
#      14 viewer.add_image(torus_image, name="torus_image")
#      15 napari.run()
#
# File ~/dev/repos/tomography/venv/lib/python3.12/site-packages/napari/viewer.py:68, in Viewer.__init__(self, title, ndisplay, order, axis_labels, show, show_welcome_screen, **kwargs)
#      64 from napari.window import Window
#      66 _initialize_plugins()
# ---> 68 self._window = Window(
#      69     self, show=show, show_welcome_screen=show_welcome_screen
#      70 )
#      71 self._instances.add(self)
#
# File ~/dev/repos/tomography/venv/lib/python3.12/site-packages/napari/_qt/qt_main_window.py:729, in Window.__init__(self, viewer, show, show_welcome_screen)
#     726 # import and index all discovered shimmed npe1 plugins
#     727 index_npe1_adapters()
# --> 729 self._add_menus()
#     730 # TODO: the dummy actions should **not** live on the layerlist context
#     731 # as they are unrelated. However, we do not currently have a suitable
#     732 # enclosing context where we could store these keys, such that they
#     733 # **and** the layerlist context key are available when we update
#     734 # menus. We need a single context to contain all keys required for
#     735 # menu update, so we add them to the layerlist context for now.
#     736 add_dummy_actions(self._qt_viewer.viewer.layers._ctx)
#
# File ~/dev/repos/tomography/venv/lib/python3.12/site-packages/napari/_qt/qt_main_window.py:1012, in Window._add_menus(self)
#    1010     self.main_menu.addMenu(self._debug_menu)
#    1011 # window menu
# -> 1012 self.window_menu = build_qmodel_menu(
#    1013     MenuId.MENUBAR_WINDOW,
#    1014     title=trans._('&Window'),
#    1015     parent=self._qt_window,
#    1016 )
#    1017 self.plugins_menu.aboutToShow.connect(
#    1018     self._update_window_menu_state,
#    1019 )
#    1020 self.main_menu.addMenu(self.window_menu)
#
# File ~/dev/repos/tomography/venv/lib/python3.12/site-packages/napari/_qt/_qapp_model/_menus.py:32, in build_qmodel_menu(menu_id, title, parent)
#      14 """Build a QModelMenu from the napari app model
#      15
#      16 Parameters
#    (...)     28     QMenu subclass populated with all items in `menu_id` menu.
#      29 """
#      30 from napari._app_model import get_app_model
# ---> 32 return QModelMenu(
#      33     menu_id=menu_id, app=get_app_model(), title=title, parent=parent
#      34 )
#
# File ~/dev/repos/tomography/venv/lib/python3.12/site-packages/app_model/backends/qt/_qmenu.py:54, in QModelMenu.__init__(self, menu_id, app, title, parent)
#      52 self._app = Application.get_or_create(app) if isinstance(app, str) else app
#      53 self.setObjectName(menu_id)
# ---> 54 self.rebuild()
#      55 self._app.menus.menus_changed.connect(self._on_registry_changed)
#      56 self.destroyed.connect(self._disconnect)
#
# File ~/dev/repos/tomography/venv/lib/python3.12/site-packages/app_model/backends/qt/_qmenu.py:93, in QModelMenu.rebuild(self, include_submenus, exclude)
#      89 def rebuild(
#      90     self, include_submenus: bool = True, exclude: Collection[str] | None = None
#      91 ) -> None:
#      92     """Rebuild menu by looking up self._menu_id in menu_registry."""
# ---> 93     _rebuild(
#      94         menu=self,
#      95         app=self._app,
#      96         menu_id=self._menu_id,
#      97         include_submenus=include_submenus,
#      98         exclude=exclude,
#      99     )
#
# File ~/dev/repos/tomography/venv/lib/python3.12/site-packages/app_model/backends/qt/_qmenu.py:314, in _rebuild(menu, app, menu_id, include_submenus, exclude)
#     309             cast("QMenu", menu).addMenu(submenu)
#     310     elif item.command.id not in _exclude:
#     311         # use QApplication instance as parent for actions
#     312         # because we use action singleton, and actions
#     313         # are not related to any window.
# --> 314         action = QMenuItemAction.create(item, app=app, parent=qapp)
#     315         menu.addAction(action)
#     316 if n < n_groups - 1:
#
# File ~/dev/repos/tomography/venv/lib/python3.12/site-packages/app_model/backends/qt/_qaction.py:200, in QMenuItemAction.create(cls, menu_item, app, parent)
#     197     res.setParent(parent)
#     198     return res
# --> 200 cls._cache[cache_key] = obj = cls(menu_item, app, parent)
#     201 return obj
#
# File ~/dev/repos/tomography/venv/lib/python3.12/site-packages/app_model/backends/qt/_qaction.py:165, in QMenuItemAction.__init__(self, menu_item, app, parent)
#     159 def __init__(
#     160     self,
#     161     menu_item: MenuItem,
#     162     app: Application | str,
#     163     parent: QObject | None = None,
#     164 ) -> None:
# --> 165     super().__init__(menu_item.command, app, parent)
#     166     self._menu_item = menu_item
#     167     with contextlib.suppress(NameError):
#
# File ~/dev/repos/tomography/venv/lib/python3.12/site-packages/app_model/backends/qt/_qaction.py:110, in QCommandRuleAction.__init__(self, command_rule, app, parent, use_short_title)
#     108 if command_rule.toggled is not None:
#     109     self.setCheckable(True)
# --> 110     self._refresh()
#     111 tooltip_with_keybinding = f"{self._tooltip} {self._keybinding_tooltip}".rstrip()
#     112 self.setToolTip(tooltip_with_keybinding)
#
# File ~/dev/repos/tomography/venv/lib/python3.12/site-packages/app_model/backends/qt/_qaction.py:138, in QCommandRuleAction._refresh(self)
#     134 if get_current := self._cmd_rule.toggled.get_current:
#     135     _current = self._app.injection_store.inject(
#     136         get_current, on_unresolved_required_args="ignore"
#     137     )
# --> 138     self.setChecked(_current())
#
# File ~/dev/repos/tomography/venv/lib/python3.12/site-packages/in_n_out/_store.py:804, in Store.inject.<locals>._inner.<locals>._exec(*args, **kwargs)
#     797 logger.debug(
#     798     "  Calling %s with %r (injected %r)",
#     799     _fname,
#     800     bound.arguments,
#     801     _injected_names,
#     802 )
#     803 try:
# --> 804     result = func(**bound.arguments)
#     805 except TypeError as e:
#     806     if "missing" not in e.args[0]:
#
# File ~/dev/repos/tomography/venv/lib/python3.12/site-packages/napari/_qt/_qapp_model/qactions/_toggle_action.py:47, in DockWidgetToggleAction.__init__.<locals>.get_current(window)
#      46 def get_current(window: Window) -> bool:
# ---> 47     dock_widget_prop = getattr(window._qt_viewer, dock_widget)
#      48     return dock_widget_prop.isVisible()
#
# File ~/dev/repos/tomography/venv/lib/python3.12/site-packages/napari/_qt/qt_viewer.py:360, in QtViewer.dockLayerControls(self)
#     356 """QWidget wrapped in a QDockWidget with forwarded viewer events."""
#     357 if self._dockLayerControls is None:
#     358     self._dockLayerControls = QtViewerDockWidget(
#     359         self,
# --> 360         self.controls,
#     361         name=trans._('layer controls'),
#     362         area='left',
#     363         allowed_areas=['left', 'right'],
#     364         object_name='layer controls',
#     365         close_btn=False,
#     366     )
#     367 return self._dockLayerControls
#
# File ~/dev/repos/tomography/venv/lib/python3.12/site-packages/napari/_qt/qt_viewer.py:305, in QtViewer.controls(self)
#     302 """Qt view for GUI controls."""
#     303 if self._controls is None:
#     304     # Avoid circular import.
# --> 305     from napari._qt.layer_controls import QtLayerControlsContainer
#     307     self._controls = QtLayerControlsContainer(self.viewer)
#     308 return self._controls
#
# File ~/dev/repos/tomography/venv/lib/python3.12/site-packages/napari/_qt/layer_controls/__init__.py:1
# ----> 1 from napari._qt.layer_controls.qt_layer_controls_container import (
#       2     QtLayerControlsContainer,
#       3 )
#       5 __all__ = ['QtLayerControlsContainer']
#
# File ~/dev/repos/tomography/venv/lib/python3.12/site-packages/napari/_qt/layer_controls/qt_layer_controls_container.py:3
#       1 from qtpy.QtWidgets import QFrame, QStackedWidget
# ----> 3 from napari._qt.layer_controls.qt_image_controls import QtImageControls
#       4 from napari._qt.layer_controls.qt_labels_controls import QtLabelsControls
#       5 from napari._qt.layer_controls.qt_points_controls import QtPointsControls
#
# File ~/dev/repos/tomography/venv/lib/python3.12/site-packages/napari/_qt/layer_controls/qt_image_controls.py:7
#       3 from napari._qt.layer_controls.qt_image_controls_base import (
#       4     QtBaseImageControls,
#       5 )
#       6 from napari._qt.layer_controls.widgets import QtProjectionModeControl
# ----> 7 from napari._qt.layer_controls.widgets._image import (
#       8     QtDepictionControl,
#       9     QtImageRenderControl,
#      10     QtInterpolationComboBoxControl,
#      11 )
#      13 if TYPE_CHECKING:
#      14     import napari.layers
#
# File ~/dev/repos/tomography/venv/lib/python3.12/site-packages/napari/_qt/layer_controls/widgets/_image/__init__.py:7
#       1 from napari._qt.layer_controls.widgets._image.qt_depiction_control import (
#       2     QtDepictionControl,
#       3 )
#       4 from napari._qt.layer_controls.widgets._image.qt_interpolation_combobox import (
#       5     QtInterpolationComboBoxControl,
#       6 )
# ----> 7 from napari._qt.layer_controls.widgets._image.qt_render_control import (
#       8     QtImageRenderControl,
#       9 )
#      11 __all__ = [
#      12     'QtDepictionControl',
#      13     'QtImageRenderControl',
#      14     'QtInterpolationComboBoxControl',
#      15 ]
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1334, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:950, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:991, in _LoaderBasics.exec_module(self, module)
#     989 'Could not get source, probably due dynamically evaluated source code.'
#
# File <frozen importlib._bootstrap_external>:1088, in SourceLoader.get_code(self, fullname)
#
# File <frozen importlib._bootstrap_external>:1187, in FileLoader.get_data(self, path)
#    1183 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyboardInterrupt:

# %% [markdown]
# # Discussion of sinograms
# Constructed from 2d intensity slices through object. 3D image reconstructed from the stacking of reconstructed 2d mages. These 2D images are reconstructed using different methods to inverse the sinogram
#
# The Fourier Slice Theorem says:
#
# The 1D Fourier transform of a projection equals a slice through the 2D Fourier transform of the image.
#
# This is the key tomography theorem.
#
# Expand on this above statement. (AI written so need to rewrite).
#
# When reconstructing, the fourier slice theorem is basically taking the intensity projections at different angles, and for each angle it is converting the intensity distribution into a frequency distribution. All of thse fourier slices need to be combined and then the inverse found to reconstruct the image. the way the slices are combined depends on the algorithm?

# %%
# Using the radon trasnform. We will start off with a full 180 degree scan of the torus, creating a detailed sinogram

# Use central slice of torus along x-y plane with z = 0
image1 = torus_image[:, :, 100]
image2 = torus_image[:, :, 120]
image3 = torus_image[:, :, 125]
# image = rescale(image, scale=0.2, mode='reflect', channel_axis=None)

fig, ((ax1, ax2), (ax3, ax4), (ax5, ax6)) = plt.subplots(3, 2, figsize=(8, 10))

ax1.set_title("Original, z = 0")
ax1.imshow(image1, cmap=plt.cm.Greys_r)

theta = np.linspace(0.0, 180.0, max(image1.shape), endpoint=False)
# Creates sinogram (radon transform used to simulate tomography)
sinogram = radon(image1, theta=theta)
dx, dy = 0.5 * 180.0 / max(image1.shape), 0.5 / sinogram.shape[0]
ax2.set_title("Radon transform\n(Sinogram) z centre")
ax2.set_xlabel("Projection angle (deg)")
ax2.set_ylabel("Projection position (pixels)")
ax2.imshow(
    sinogram,
    cmap=plt.cm.Greys_r,
    extent=(-dx, 180.0 + dx, -dy, sinogram.shape[0] + dy),
    aspect="auto",
)

ax3.set_title("Original, z medium")
ax3.imshow(image2, cmap=plt.cm.Greys_r)

theta = np.linspace(0.0, 180.0, max(image2.shape), endpoint=False)
# Creates sinogram (radon transform used to simulate tomography)
sinogram = radon(image2, theta=theta)
dx, dy = 0.5 * 180.0 / max(image2.shape), 0.5 / sinogram.shape[0]
ax4.set_title("Radon transform\n(Sinogram) z centre")
ax4.set_xlabel("Projection angle (deg)")
ax4.set_ylabel("Projection position (pixels)")
ax4.imshow(
    sinogram,
    cmap=plt.cm.Greys_r,
    extent=(-dx, 180.0 + dx, -dy, sinogram.shape[0] + dy),
    aspect="auto",
)


ax5.set_title("Original, z high")
ax5.imshow(image3, cmap=plt.cm.Greys_r)

theta = np.linspace(0.0, 180.0, max(image3.shape), endpoint=False)
# Creates sinogram (radon transform used to simulate tomography)
sinogram = radon(image3, theta=theta)
dx, dy = 0.5 * 180.0 / max(image3.shape), 0.5 / sinogram.shape[0]
ax6.set_title("Radon transform\n(Sinogram) z centre")
ax6.set_xlabel("Projection angle (deg)")
ax6.set_ylabel("Projection position (pixels)")
ax6.imshow(
    sinogram,
    cmap=plt.cm.Greys_r,
    extent=(-dx, 180.0 + dx, -dy, sinogram.shape[0] + dy),
    aspect="auto",
)

fig.tight_layout()
plt.savefig("torus-sinogram")
plt.show()

# %% [markdown]
# # How errors arise in FBP
# Hard to compute inverse radon transform, the algorithms are approximations of the true inverse. There are also errors due to the rotation of the immage arrays and the interpolation used to fit rotated values tointeger grid points.

# %%
# Displaying reconstructed image along with error -code modified from  scikit-image radon function examples
image = torus_image[:, :, 100]
sinogram = radon(image, theta=theta)

reconstruction_fbp = iradon(sinogram, theta=theta, filter_name="ramp")
error = reconstruction_fbp - image
print(f"FBP rms reconstruction error: {np.sqrt(np.mean(error**2)):.3g}")

imkwargs = dict(vmin=-0.2, vmax=0.2)
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(8, 4.5))
ax1.set_title("Original image")
ax1.imshow(image, cmap=plt.cm.Greys_r)
ax2.set_title("Reconstruction\nFiltered back projection")
ax2.imshow(reconstruction_fbp, cmap=plt.cm.Greys_r)
ax3.set_title("Reconstruction error\nFiltered back projection")
ax3.imshow(reconstruction_fbp - image, cmap=plt.cm.Greys_r, **imkwargs)
plt.savefig("fbp-mse-err")
plt.show()
# Out:
# FBP rms reconstruction error: 0.0387

# %%
# Code from scikit image radon examples
image = torus_image[:, :, 100]
sinogram = radon(image, theta=theta)

reconstruction_sart = iradon_sart(sinogram, theta=theta)
error = reconstruction_sart - image
print(
    f"SART (1 iteration) rms reconstruction error: " f"{np.sqrt(np.mean(error**2)):.3g}"
)

fig, axes = plt.subplots(3, 2, figsize=(8, 8.5))
ax = axes.ravel()

ax[0].set_title("Reconstruction\nSART")
ax[0].imshow(reconstruction_sart, cmap=plt.cm.Greys_r)

ax[1].set_title("Reconstruction error\nSART")
ax[1].imshow(reconstruction_sart - image, cmap=plt.cm.Greys_r, **imkwargs)

# Run a second iteration of SART by supplying the reconstruction
# from the first iteration as an initial estimate
reconstruction_sart2 = iradon_sart(sinogram, theta=theta, image=reconstruction_sart)
error = reconstruction_sart2 - image
print(
    f"SART (2 iterations) rms reconstruction error: "
    f"{np.sqrt(np.mean(error**2)):.3g}"
)

ax[2].set_title("Reconstruction\nSART, 2 iterations")
ax[2].imshow(reconstruction_sart2, cmap=plt.cm.Greys_r)

ax[3].set_title("Reconstruction error\nSART, 2 iterations")
ax[3].imshow(reconstruction_sart2 - image, cmap=plt.cm.Greys_r, **imkwargs)

# Run a tenth iteration of SART by supplying the reconstruction
# from the first iteration as an initial estimate
reconstruction_sart_n = reconstruction_sart
for i in range(9):
    reconstruction_sart_n = iradon_sart(
        sinogram, theta=theta, image=reconstruction_sart_n
    )

error = reconstruction_sart_n - image
print(
    f"SART (10 iterations) rms reconstruction error: "
    f"{np.sqrt(np.mean(error**2)):.3g}"
)

ax[4].set_title("Reconstruction\nSART, 10 iterations")
ax[4].imshow(reconstruction_sart_n, cmap=plt.cm.Greys_r)

ax[5].set_title("Reconstruction error\nSART, 10 iterations")
ax[5].imshow(reconstruction_sart_n - image, cmap=plt.cm.Greys_r, **imkwargs)

fig.tight_layout()
plt.savefig("iterative-reconstruction-mse-decrease")
plt.show()
# Out:
# SART (1 iteration) rms reconstruction error: 0.0453
# SART (2 iterations) rms reconstruction error: 0.0377
# SART (10 iterations) rms reconstruction error: 0.0293

# %% [markdown]
# # Reconstruct sparse sinogram using iterative reconstruction techniques
#
# Notice that SART error increases as it starts fitting artefacts. Mention this

# %%
theta_sparse = np.linspace(0, 180, 5, endpoint=False)
sparse_sinogram = radon(image, theta=theta_sparse)

reconstruction_fbp = iradon(sparse_sinogram, theta=theta_sparse, filter_name="ramp")
error = reconstruction_fbp - image
print(f"FBP MSE reconstruction error: {np.mean(error**2):.3g}")
print(
    f"FBP SSIM reconstruction error: {ssim(image, reconstruction_fbp, data_range = np.max(image)-np.min(image)):.3g}"
)

imkwargs = dict(vmin=-0.2, vmax=0.2)
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(14, 4.5))
ax1.set_title("Original image")
ax1.imshow(image, cmap=plt.cm.Greys_r)
dx, dy = 0.5 * 180.0 / max(image.shape), 0.5 / sparse_sinogram.shape[0]
ax2.set_title("Radon transform\n(Sparse Sinogram) z centre")
ax2.set_xlabel("Projection angle (deg)")
ax2.set_ylabel("Projection position (pixels)")
ax2.imshow(
    sparse_sinogram,
    cmap=plt.cm.Greys_r,
    extent=(-dx, 180.0 + dx, -dy, sparse_sinogram.shape[0] + dy),
    aspect="auto",
)
ax3.set_title("Reconstruction\nFiltered back projection")
ax3.imshow(reconstruction_fbp, cmap=plt.cm.Greys_r)
plt.show()
plt.savefig("sparse-sinogram-reconstruction-fbp")

reconstruction_sart = iradon_sart(sparse_sinogram, theta=theta_sparse)
error = reconstruction_sart - image
print(
    f"SART (1 iteration) rms reconstruction error: " f"{np.sqrt(np.mean(error**2)):.3g}"
)

fig, axes = plt.subplots(3, 2, figsize=(5.5, 8.5))
ax = axes.ravel()

ax[0].set_title("Reconstruction\nSART")
ax[0].imshow(reconstruction_sart, cmap=plt.cm.Greys_r)

ax[1].set_title("Reconstruction error\nSART")
ax[1].imshow(reconstruction_sart - image, cmap=plt.cm.Greys_r, **imkwargs)

# Run a second iteration of SART by supplying the reconstruction
# from the first iteration as an initial estimate
reconstruction_sart2 = iradon_sart(
    sparse_sinogram, theta=theta_sparse, image=reconstruction_sart
)
error = reconstruction_sart2 - image
print(
    f"SART (2 iterations) rms reconstruction error: "
    f"{np.sqrt(np.mean(error**2)):.3g}"
)

ax[2].set_title("Reconstruction\nSART, 2 iterations")
ax[2].imshow(reconstruction_sart2, cmap=plt.cm.Greys_r)

ax[3].set_title("Reconstruction error\nSART, 2 iterations")
ax[3].imshow(reconstruction_sart2 - image, cmap=plt.cm.Greys_r, **imkwargs)

# Run a tenth iteration of SART by supplying the reconstruction
# from the first iteration as an initial estimate
reconstruction_sart_n = reconstruction_sart
for i in range(9):
    reconstruction_sart_n = iradon_sart(
        sparse_sinogram, theta=theta_sparse, image=reconstruction_sart_n
    )

error = reconstruction_sart_n - image
print(
    f"SART (10 iterations) rms reconstruction error: "
    f"{np.sqrt(np.mean(error**2)):.3g}"
)

ax[4].set_title("Reconstruction\nSART, 10 iterations")
ax[4].imshow(reconstruction_sart_n, cmap=plt.cm.Greys_r)

ax[5].set_title("Reconstruction error\nSART, 10 iterations")
ax[5].imshow(reconstruction_sart_n - image, cmap=plt.cm.Greys_r, **imkwargs)

fig.tight_layout()
plt.savefig("sparse-sinogram-reconstruction-sart")
plt.show()
# Out:
# FBP MSE reconstruction error: 0.19
# FBP SSIM reconstruction error: 0.216
# SART (1 iteration) rms reconstruction error: 0.266
# SART (2 iterations) rms reconstruction error: 0.181
# SART (10 iterations) rms reconstruction error: 0.125

# %% [markdown]
# # Comparison of errors between FBP, SART and SART + TV denoising
#
# First calculate MSE error, simple to do but is not always indicative of the perceived similarity between images that may be mathematically similar. This method calulates total difference in pixel intensities of two images, by subtracting the intensity values of matching pixels for every pixel in the image. The resulting 'error' is squared, and the mean calculated. Note that units of MSE are squared units of intensity, and root mean squared error (RMSE) may provide a better perceived visualisation of image error.
#
# Another way of comparing images is the Structural Similarity Index, or SSIM. This takes texture into account, and will be calculated using scikit-image's ssim function. It is a perception based method of calculating image similarity, whereas MSE is not perception based. Evidence shows that SSIM may align more closely with the way that we perceive differences in images.
#
#
# Both errors are measured, for 3 recomstructive techniques, Filtered Back Projection, SART and a modified SART wth additional Total Variation (TV) denoising. This is implemented again using scikit-image's TV filter. Errors were calculated for a range of images, with increasingly fewer angles. This simulates a constricted lab environment where due to experimental constraints, only limited intensity distributions can be collected. Limited angle topography is characterised by incomplete sinograms. The problem of reconstructing an accurate image becomes more difficult, as there is less initial data.

# %%
image = torus_image[:, :, 100]
print(image.shape)
image = shepp_logan_phantom()
print(image.shape)
# Out:
# (200, 200)
# (400, 400)

# %%
num_projections = generate_num_projections(10)

image = io.imread("images/cells.tif")[32, :, :]
# downsampling cells image
image = resize(image, (image.shape[0] // 2, image.shape[1] // 2), anti_aliasing=True)
iterations = 15

num_desired_slices = np.arange(3, 50, step=1)
mse_fbp = []
ssim_fbp = []
mse_sart = []
ssim_sart = []
mse_modified_sart = []
ssim_modified_sart = []
for i in num_desired_slices:
    sparse_sinogram = generate_sparse_sinogram(image, i)
    reconstruction_fbp = iradon(sparse_sinogram)
    mse_fbp.append(calculate_mse(image, reconstruction_fbp))
    ssim_fbp.append(calculate_ssim(image, reconstruction_fbp))
    reconstruction_sart = iterative_sart(sparse_sinogram, iterations=iterations)
    mse_sart.append(calculate_mse(image, reconstruction_sart))
    ssim_sart.append(calculate_ssim(image, reconstruction_sart))
    reconstruction_modified_sart = modified_sart_plus_tv(
        sparse_sinogram, weight=0.01, iterations=iterations
    )
    mse_modified_sart.append(calculate_mse(image, reconstruction_modified_sart))
    ssim_modified_sart.append(calculate_ssim(image, reconstruction_modified_sart))


# curve fitting with expontential function
def func(x, a, b, c):
    return a * np.exp(-b * x) + c


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))
ax1.set_title("MSE for FBP vs SART vs modified SART")
ax1.set_xlabel("Number of angles imaged")
ax1.set_ylabel("MSE score (intensity$^2$)")
ax1.grid()

# plot SART MSE vals
ax1.scatter(
    num_desired_slices,
    mse_sart,
    label="SART: " + str(iterations) + " iterations",
    alpha=0.4,
)

popt, pcov = curve_fit(func, num_desired_slices, mse_sart, p0=[1, 0.5, 0])
ax1.plot(
    num_desired_slices,
    func(num_desired_slices, *popt),
    "r-",
    color="red",
)

# plot modified SART MSE vals
ax1.scatter(
    num_desired_slices,
    mse_modified_sart,
    label="modified SART: " + str(iterations) + " iterations",
    alpha=0.4,
)
popt, pcov = curve_fit(func, num_desired_slices, mse_modified_sart, p0=[1, 0.5, 0])
ax1.plot(
    num_desired_slices,
    func(num_desired_slices, *popt),
    "r-",
    color="blue",
)

# plot FBP MSE vals
ax1.scatter(num_desired_slices, mse_fbp, label="FBP", alpha=0.4)
popt, pcov = curve_fit(func, num_desired_slices, mse_fbp, p0=[1, 0.5, 0])
ax1.plot(
    num_desired_slices,
    func(num_desired_slices, *popt),
    "r-",
    color="green",
)

ax2.set_title("SSIM for FBP vs SART vs modified SART")
ax2.set_xlabel("Number of angles imaged")
ax2.set_ylabel("SSIM score")
ax2.grid()

# plot SART SSIM vals
ax2.scatter(
    num_desired_slices,
    ssim_sart,
    label="SART: " + str(iterations) + " iterations",
    alpha=0.4,
)
popt, pcov = curve_fit(func, num_desired_slices, ssim_sart, p0=[-1, 0.5, 1])
ax2.plot(
    num_desired_slices,
    func(num_desired_slices, *popt),
    "r-",
    color="red",
)

# plot modified SART SSIM vals
ax2.scatter(
    num_desired_slices,
    ssim_modified_sart,
    label="modified SART: " + str(iterations) + " iterations",
    alpha=0.4,
)
popt, pcov = curve_fit(func, num_desired_slices, ssim_modified_sart, p0=[-1, 0.5, 1])
ax2.plot(
    num_desired_slices,
    func(num_desired_slices, *popt),
    "r-",
    color="blue",
)

ax2.scatter(num_desired_slices, ssim_fbp, label=" FBP", alpha=0.4)

popt, pcov = curve_fit(func, num_desired_slices, ssim_fbp, p0=[-1, 0.5, 1])
ax2.plot(
    num_desired_slices,
    func(num_desired_slices, *popt),
    "r-",
    color="green",
)

ax1.legend()
ax2.legend()
plt.savefig("mse-versus-ssim")
plt.show()
# Out:
# /home/msmith693/dev/repos/tomography/venv/lib/python3.12/site-packages/skimage/transform/radon_transform.py:74: UserWarning: Radon transform: image must be zero outside the reconstruction circle
#   warn(
# /tmp/ipykernel_1249636/2415669911.py:45: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax1.plot(
# /tmp/ipykernel_1249636/2415669911.py:60: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax1.plot(
# /tmp/ipykernel_1249636/2415669911.py:70: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax1.plot(
# /tmp/ipykernel_1249636/2415669911.py:90: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax2.plot(
# /tmp/ipykernel_1249636/2415669911.py:105: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax2.plot(
# /tmp/ipykernel_1249636/2415669911.py:115: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax2.plot(

# %%
image = io.imread("images/cells.tif")[32, :, :]
# downsampling cells image
image = resize(image, (image.shape[0] // 2, image.shape[1] // 2), anti_aliasing=True)


# example of bad naming. There are two different types of projections, an integer passed into generate_sparse_sinogram and an array of projections that needs to be passed into sart functions.
projection_array = generate_num_projections(25)

sparse_sinogram = generate_sparse_sinogram(image, 25)


reconstruction_modified_sart = modified_sart_plus_tv(
    sparse_sinogram, theta=projection_array, weight=0.001, iterations=10
)

reconstruction_fbp = iradon(sparse_sinogram, theta=projection_array, filter_name="ramp")

reconstruction_sart = iradon_sart(sparse_sinogram, theta=projection_array)

# imkwargs = dict(vmin=-0.2, vmax=0.2)
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(20, 10))

fig.suptitle(
    "Image reconstruction for FBP, SART and SART+TV algorithms",
    y=0.75,
    fontsize=24,
)
ax1.set_title("Original image")
ax1.imshow(image, cmap=plt.cm.Greys_r)
ax2.set_title("FBP")
ax2.imshow(reconstruction_fbp, cmap=plt.cm.Greys_r)
ax3.set_title("SART")
ax3.imshow(reconstruction_sart, cmap=plt.cm.Greys_r)
ax4.set_title("SART+TV")
ax4.imshow(reconstruction_modified_sart, cmap=plt.cm.Greys_r)

fig.tight_layout()
plt.savefig("/images/circular-reconstruction-artefact")
plt.show()
# Out:
# /home/msmith693/dev/repos/tomography/venv/lib/python3.12/site-packages/skimage/transform/radon_transform.py:74: UserWarning: Radon transform: image must be zero outside the reconstruction circle
#   warn(
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[21], line 38
#      34 ax4.set_title("SART+TV")
#      35 ax4.imshow(reconstruction_modified_sart, cmap=plt.cm.Greys_r)
#      36
#      37 fig.tight_layout()
# ---> 38 plt.savefig("/images/circular-reconstruction-artefact")
#      39 plt.show()
#
# File ~/dev/repos/tomography/venv/lib/python3.12/site-packages/matplotlib/pyplot.py:1250, in savefig(*args, **kwargs)
#    1247 fig = gcf()
#    1248 # savefig default implementation has no return, so mypy is unhappy
#    1249 # presumably this is here because subclasses can return?
# -> 1250 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1251 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1252 return res
#
# File ~/dev/repos/tomography/venv/lib/python3.12/site-packages/matplotlib/figure.py:3497, in Figure.savefig(self, fname, transparent, **kwargs)
#    3495     for ax in self.axes:
#    3496         _recursively_make_axes_transparent(stack, ax)
# -> 3497 self.canvas.print_figure(fname, **kwargs)
#
# File ~/dev/repos/tomography/venv/lib/python3.12/site-packages/matplotlib/backend_bases.py:2186, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2182 try:
#    2183     # _get_renderer may change the figure dpi (as vector formats
#    2184     # force the figure dpi to 72), so we need to set it again here.
#    2185     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2186         result = print_method(
#    2187             filename,
#    2188             facecolor=facecolor,
#    2189             edgecolor=edgecolor,
#    2190             orientation=orientation,
#    2191             bbox_inches_restore=_bbox_inches_restore,
#    2192             **kwargs)
#    2193 finally:
#    2194     if bbox_inches and restore_bbox:
#
# File ~/dev/repos/tomography/venv/lib/python3.12/site-packages/matplotlib/backend_bases.py:2042, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2038     optional_kws = {  # Passed by print_figure for other renderers.
#    2039         "dpi", "facecolor", "edgecolor", "orientation",
#    2040         "bbox_inches_restore"}
#    2041     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2042     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2043         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2044 else:  # Let third-parties do as they see fit.
#    2045     print_method = meth
#
# File ~/dev/repos/tomography/venv/lib/python3.12/site-packages/matplotlib/backends/backend_agg.py:481, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     434 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     435     """
#     436     Write the figure to a PNG file.
#     437
#    (...)    479         *metadata*, including the default 'Software' key.
#     480     """
# --> 481     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File ~/dev/repos/tomography/venv/lib/python3.12/site-packages/matplotlib/backends/backend_agg.py:430, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     425 """
#     426 Draw the canvas, then save it using `.image.imsave` (to which
#     427 *pil_kwargs* and *metadata* are forwarded).
#     428 """
#     429 FigureCanvasAgg.draw(self)
# --> 430 mpl.image.imsave(
#     431     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     432     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File ~/dev/repos/tomography/venv/lib/python3.12/site-packages/matplotlib/image.py:1657, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1655 pil_kwargs.setdefault("format", format)
#    1656 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1657 image.save(fname, **pil_kwargs)
#
# File ~/dev/repos/tomography/venv/lib/python3.12/site-packages/PIL/Image.py:2708, in Image.save(self, fp, format, **params)
#    2706         fp = builtins.open(filename, "r+b")
#    2707     else:
# -> 2708         fp = builtins.open(filename, "w+b")
#    2709 else:
#    2710     fp = cast(IO[bytes], fp)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/images/circular-reconstruction-artefact.png'

# %%
# import numpy as np
# import matplotlib.pyplot as plt
# from matplotlib import cm
# from matplotlib.ticker import LinearLocator
# import napari
# from skimage.transform import radon, resize
# from skimage.transform import iradon, iradon_sart
# from skimage.metrics import structural_similarity as ssim
# from scipy.optimize import curve_fit
# from src.functions import (  # self defined (somewhat)
#     generate_num_projections,
#     generate_sparse_sinogram,
#     order_angles_golden_ratio,
#     modified_sart_plus_tv,
#     add_salt_pepper,
#     add_gaussian_noise,
#     calculate_ssim,
#     calculate_mse,
#     iterative_sart,
# )
# from skimage.data import shepp_logan_phantom
# from skimage import io

# %%
from warnings import warn
from skimage.transform.radon_transform import sart_projection_update

phantom = shepp_logan_phantom()
# downsampling shepp logan phantom image
phantom = resize(
    phantom, (phantom.shape[0] // 2, phantom.shape[1] // 2), anti_aliasing=True
)
noisy_phantom = add_salt_pepper(add_gaussian_noise(phantom), 0.05)
cells = io.imread("images/cells.tif")[32, :, :]
# downsampling cells image
cells = resize(cells, (cells.shape[0] // 2, cells.shape[1] // 2), anti_aliasing=True)

num_desired_slices = np.arange(3, 50, step=1)
ssim_fbp_phantom = []
ssim_sart_phantom = []
ssim_modified_sart_phantom = []
ssim_fbp_noisy_phantom = []
ssim_sart_noisy_phantom = []
ssim_modified_sart_noisy_phantom = []
ssim_fbp_cells = []
ssim_sart_cells = []
ssim_modified_sart_cells = []
for i in num_desired_slices:
    # calculate phantom error
    sparse_sinogram_phantom = generate_sparse_sinogram(phantom, i)
    reconstruction_fbp_phantom = iradon(sparse_sinogram_phantom)
    ssim_fbp_phantom.append(calculate_ssim(phantom, reconstruction_fbp_phantom))
    reconstruction_sart_phantom = iterative_sart(sparse_sinogram_phantom, iterations=15)
    ssim_sart_phantom.append(calculate_ssim(phantom, reconstruction_sart_phantom))
    reconstruction_modified_sart_phantom = modified_sart_plus_tv(
        sparse_sinogram_phantom, weight=0.05, iterations=15
    )
    ssim_modified_sart_phantom.append(
        calculate_ssim(phantom, reconstruction_modified_sart_phantom)
    )

    # calculate noisy phantom error
    sparse_sinogram_noisy_phantom = generate_sparse_sinogram(noisy_phantom, i)
    reconstruction_fbp_noisy_phantom = iradon(sparse_sinogram_noisy_phantom)
    ssim_fbp_noisy_phantom.append(
        calculate_ssim(noisy_phantom, reconstruction_fbp_noisy_phantom)
    )
    reconstruction_sart_noisy_phantom = iterative_sart(
        sparse_sinogram_noisy_phantom, iterations=15
    )
    ssim_sart_noisy_phantom.append(
        calculate_ssim(noisy_phantom, reconstruction_sart_noisy_phantom)
    )
    reconstruction_modified_sart_noisy_phantom = modified_sart_plus_tv(
        sparse_sinogram_noisy_phantom, weight=0.05, iterations=15
    )
    ssim_modified_sart_noisy_phantom.append(
        calculate_ssim(noisy_phantom, reconstruction_modified_sart_noisy_phantom)
    )

    # calculate cells error
    sparse_sinogram_cells = generate_sparse_sinogram(cells, i)
    reconstruction_fbp_cells = iradon(sparse_sinogram_cells)
    ssim_fbp_cells.append(calculate_ssim(cells, reconstruction_fbp_cells))
    reconstruction_sart_cells = iterative_sart(sparse_sinogram_cells, iterations=15)
    ssim_sart_cells.append(calculate_ssim(cells, reconstruction_sart_cells))
    reconstruction_modified_sart_cells = modified_sart_plus_tv(
        sparse_sinogram_cells, weight=0.05, iterations=15
    )
    ssim_modified_sart_cells.append(
        calculate_ssim(cells, reconstruction_modified_sart_cells)
    )


# curve fitting with expontential function
def func(x, a, b, c):
    return a * np.exp(-b * x) + c


fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15, 6))
fig.suptitle(
    "Errors for reconstruction algorithms on simulated and real data",
    fontsize=24,
)
fig.supxlabel("Number of angles imaged")
fig.supylabel("SSIM score")

ax1.set_title("Shepp Logan phantom")
ax1.grid()

# plot SART SSIM vals
ax1.scatter(num_desired_slices, ssim_sart_phantom, label="SART", alpha=0.4)
popt, pcov = curve_fit(func, num_desired_slices, ssim_sart_phantom, p0=[-1, 0.5, 1])
ax1.plot(
    num_desired_slices,
    func(num_desired_slices, *popt),
    "r-",
    label=rf"fit: ${popt[0]:.2f} \cdot \mathrm{{exp}}(-{popt[1]:.2f}x) + {popt[2]:.2f}$",
    color="red",
)

# plot modified SART SSIM vals
ax1.scatter(
    num_desired_slices, ssim_modified_sart_phantom, label="modified SART", alpha=0.4
)
popt, pcov = curve_fit(
    func, num_desired_slices, ssim_modified_sart_phantom, p0=[-1, 0.5, 1]
)
ax1.plot(
    num_desired_slices,
    func(num_desired_slices, *popt),
    "r-",
    label=rf"fit: ${popt[0]:.2f} \cdot \mathrm{{exp}}(-{popt[1]:.2f}x) + {popt[2]:.2f}$",
    color="blue",
)

ax1.scatter(num_desired_slices, ssim_fbp_phantom, label="FBP", alpha=0.4)

popt, pcov = curve_fit(func, num_desired_slices, ssim_fbp_phantom, p0=[-1, 0.5, 1])
ax1.plot(
    num_desired_slices,
    func(num_desired_slices, *popt),
    "r-",
    label=rf"fit: ${popt[0]:.2f} \cdot \mathrm{{exp}}(-{popt[1]:.2f}x) + {popt[2]:.2f}$",
    color="green",
)

########################################

ax2.set_title("Shepp Logan noisy phantom")
ax2.grid()

# plot SART SSIM vals
ax2.scatter(num_desired_slices, ssim_sart_noisy_phantom, label="SART", alpha=0.4)
popt, pcov = curve_fit(
    func, num_desired_slices, ssim_sart_noisy_phantom, p0=[-1, 0.5, 1]
)
ax2.plot(
    num_desired_slices,
    func(num_desired_slices, *popt),
    "r-",
    label=rf"fit: ${popt[0]:.2f} \cdot \mathrm{{exp}}(-{popt[1]:.2f}x) + {popt[2]:.2f}$",
    color="red",
)

# plot modified SART SSIM vals
ax2.scatter(
    num_desired_slices,
    ssim_modified_sart_noisy_phantom,
    label="modified SART",
    alpha=0.4,
)
popt, pcov = curve_fit(
    func, num_desired_slices, ssim_modified_sart_noisy_phantom, p0=[-1, 0.5, 1]
)
ax2.plot(
    num_desired_slices,
    func(num_desired_slices, *popt),
    "r-",
    label=rf"fit: ${popt[0]:.2f} \cdot \mathrm{{exp}}(-{popt[1]:.2f}x) + {popt[2]:.2f}$",
    color="blue",
)

ax2.scatter(num_desired_slices, ssim_fbp_noisy_phantom, label=" FBP", alpha=0.4)

popt, pcov = curve_fit(
    func, num_desired_slices, ssim_fbp_noisy_phantom, p0=[-1, 0.5, 1]
)
ax2.plot(
    num_desired_slices,
    func(num_desired_slices, *popt),
    "r-",
    label=rf"fit: ${popt[0]:.2f} \cdot \mathrm{{exp}}(-{popt[1]:.2f}x) + {popt[2]:.2f}$",
    color="green",
)

#####################################

ax3.set_title("Cells image")
ax3.grid()

# plot SART SSIM vals
ax3.scatter(num_desired_slices, ssim_sart_cells, label="SART", alpha=0.4)
popt, pcov = curve_fit(func, num_desired_slices, ssim_sart_cells, p0=[-1, 0.5, 1])
ax3.plot(
    num_desired_slices,
    func(num_desired_slices, *popt),
    "r-",
    label=rf"fit: ${popt[0]:.2f} \cdot \mathrm{{exp}}(-{popt[1]:.2f}x) + {popt[2]:.2f}$",
    color="red",
)

# plot modified SART SSIM vals
ax3.scatter(
    num_desired_slices, ssim_modified_sart_cells, label="modified SART", alpha=0.4
)
popt, pcov = curve_fit(
    func, num_desired_slices, ssim_modified_sart_cells, p0=[-1, 0.5, 1]
)
ax3.plot(
    num_desired_slices,
    func(num_desired_slices, *popt),
    "r-",
    label=rf"fit: ${popt[0]:.2f} \cdot \mathrm{{exp}}(-{popt[1]:.2f}x) + {popt[2]:.2f}$",
    color="blue",
)

ax3.scatter(num_desired_slices, ssim_fbp_cells, label=" FBP", alpha=0.4)

popt, pcov = curve_fit(func, num_desired_slices, ssim_fbp_cells, p0=[-1, 0.5, 1])
ax3.plot(
    num_desired_slices,
    func(num_desired_slices, *popt),
    "r-",
    label=rf"fit: ${popt[0]:.2f} \cdot \mathrm{{exp}}(-{popt[1]:.2f}x) + {popt[2]:.2f}$",
    color="green",
)

ax1.legend(fontsize=8)
ax2.legend(fontsize=8)
ax3.legend(fontsize=8)
plt.show()
plt.savefig("/images/multiple-iterations-reconstruction-errors")
# Out:
# /home/msmith693/dev/repos/tomography/venv/lib/python3.12/site-packages/skimage/transform/radon_transform.py:74: UserWarning: Radon transform: image must be zero outside the reconstruction circle
#   warn(
# /tmp/ipykernel_1249636/1943743974.py:90: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax1.plot(
# /tmp/ipykernel_1249636/1943743974.py:105: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax1.plot(
# /tmp/ipykernel_1249636/1943743974.py:116: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax1.plot(
# /tmp/ipykernel_1249636/1943743974.py:134: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax2.plot(
# /tmp/ipykernel_1249636/1943743974.py:152: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax2.plot(
# /tmp/ipykernel_1249636/1943743974.py:165: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax2.plot(
# /tmp/ipykernel_1249636/1943743974.py:181: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax3.plot(
# /tmp/ipykernel_1249636/1943743974.py:196: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax3.plot(
# /tmp/ipykernel_1249636/1943743974.py:207: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   ax3.plot(
